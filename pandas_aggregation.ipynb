# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')

# %%
df.sum()
# Out:
# fixed acidity           13303.10000
# volatile acidity          843.98500
# citric acid               433.29000
# residual sugar           4059.55000
# chlorides                 139.85900
# free sulfur dioxide     25384.00000
# total sulfur dioxide    74302.00000
# density                  1593.79794
# pH                       5294.47000
# sulphates                1052.38000
# alcohol                 16666.35000
# quality                  9012.00000
# dtype: float64

# %%
print(df.sulphates.sum())
print(df['fixed acidity'].sum())
# Out:
# 1052.3799999999999

# %%
print(f"Unique quality: {df['quality'].unique()}")
# Out:
# Unique quality: [5 6 7 4 8 3]

# %%
df.groupby("quality").mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
df.groupby(["quality", "residual sugar"]).mean()
# Out:
#                         fixed acidity  volatile acidity  citric acid  \
# quality residual sugar
# 3       1.2                  6.800000          0.815000         0.00
#         1.5                 10.400000          0.440000         0.42
#         1.8                  6.700000          0.760000         0.02
#         2.1                  8.433333          1.056667         0.18
#         2.2                 11.600000          0.580000         0.66
# ...                               ...               ...          ...
# 8       2.6                 10.700000          0.350000         0.53
#         2.8                  9.400000          0.300000         0.56
#         3.6                  7.900000          0.350000         0.46
#         5.2                 11.300000          0.620000         0.67
#         6.4                 10.300000          0.320000         0.45
#
#                         chlorides  free sulfur dioxide  total sulfur dioxide  \
# quality residual sugar
# ...

# %%
df.groupby(["quality"])["alcohol"].mean()
# Out:
# quality
# 3     9.955000
# 4    10.265094
# 5     9.899706
# 6    10.629519
# 7    11.465913
# 8    12.094444
# Name: alcohol, dtype: float64

# %%
df.groupby("quality", as_index=False).mean()
# Out:
#    quality  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        3       8.360000          0.884500     0.171000        2.635000
# 1        4       7.779245          0.693962     0.174151        2.694340
# 2        5       8.167254          0.577041     0.243686        2.528855
# 3        6       8.347179          0.497484     0.273824        2.477194
# 4        7       8.872362          0.403920     0.375176        2.720603
# 5        8       8.566667          0.423333     0.391111        2.577778
#
#    chlorides  free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0   0.122500            11.000000             24.900000  0.997464  3.398000
# 1   0.090679            12.264151             36.245283  0.996542  3.381509
# 2   0.092736            16.983847             56.513950  0.997104  3.304949
# 3   0.084956            15.711599             40.869906  0.996615  3.318072
# ...

# %%
grouped = df.groupby("quality")
grouped.describe()
# Out:
#         fixed acidity                                                     \
#                 count      mean       std  min   25%   50%     75%   max
# quality
# 3                10.0  8.360000  1.770875  6.7  7.15  7.50   9.875  11.6
# 4                53.0  7.779245  1.626624  4.6  6.80  7.50   8.400  12.5
# 5               681.0  8.167254  1.563988  5.0  7.10  7.80   8.900  15.9
# 6               638.0  8.347179  1.797849  4.7  7.00  7.90   9.400  14.3
# 7               199.0  8.872362  1.992483  4.9  7.40  8.80  10.100  15.6
# 8                18.0  8.566667  2.119656  5.0  7.25  8.25  10.225  12.6
#
#         volatile acidity            ... sulphates       alcohol             \
#                    count      mean  ...       75%   max   count       mean
# quality                             ...
# 3                   10.0  0.884500  ...     0.615  0.86    10.0   9.955000
# 4                   53.0  0.693962  ...     0.600  2.00    53.0  10.265094
# ...

# %%
grouped.describe()["fixed acidity"]
# Out:
#          count      mean       std  min   25%   50%     75%   max
# quality
# 3         10.0  8.360000  1.770875  6.7  7.15  7.50   9.875  11.6
# 4         53.0  7.779245  1.626624  4.6  6.80  7.50   8.400  12.5
# 5        681.0  8.167254  1.563988  5.0  7.10  7.80   8.900  15.9
# 6        638.0  8.347179  1.797849  4.7  7.00  7.90   9.400  14.3
# 7        199.0  8.872362  1.992483  4.9  7.40  8.80  10.100  15.6
# 8         18.0  8.566667  2.119656  5.0  7.25  8.25  10.225  12.6

# %%
df.loc[grouped.groups[3]]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 459            11.6             0.580         0.66            2.20      0.074
# 517            10.4             0.610         0.49            2.10      0.200
# 690             7.4             1.185         0.00            4.25      0.097
# 832            10.4             0.440         0.42            1.50      0.145
# 899             8.3             1.020         0.02            3.40      0.084
# 1299            7.6             1.580         0.00            2.10      0.137
# 1374            6.8             0.815         0.00            1.20      0.267
# 1469            7.3             0.980         0.05            2.10      0.061
# 1478            7.1             0.875         0.05            5.70      0.082
# 1505            6.7             0.760         0.02            1.80      0.078
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# Advanced Aggregation

# %%
df.agg(["sum", "mean", "std"])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  \
# sum    13303.100000        843.985000   433.290000     4059.550000
# mean       8.319637          0.527821     0.270976        2.538806
# std        1.741096          0.179060     0.194801        1.409928
#
#        chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# sum   139.859000         25384.000000          74302.000000  1593.797940
# mean    0.087467            15.874922             46.467792     0.996747
# std     0.047065            10.460157             32.895324     0.001887
#
#                pH    sulphates       alcohol      quality
# sum   5294.470000  1052.380000  16666.350000  9012.000000
# mean     3.311113     0.658149     10.422983     5.636023
# std      0.154386     0.169507      1.065668     0.807569

# %%
df[["fixed acidity", "volatile acidity"]].agg(["sum", "mean", "std"])
# Out:
#       fixed acidity  volatile acidity
# sum    13303.100000        843.985000
# mean       8.319637          0.527821
# std        1.741096          0.179060

# %%
# agg function using a dictionary format
df.agg({
    "fixed acidity": ["sum", "mean", "median"],
    "volatile acidity": ["sum", "mean", "std"]
})
# Out:
#         fixed acidity  volatile acidity
# sum      13303.100000        843.985000
# mean         8.319637          0.527821
# median       7.900000               NaN
# std               NaN          0.179060

# %%
# groupby & agg function using a dictionary format
df_grouped = df.groupby("quality").agg({
    "fixed acidity": ["sum", "mean", "std"],
    "volatile acidity": ["sum", "mean", "std"]
})
df_grouped
# Out:
#         fixed acidity                     volatile acidity
#                   sum      mean       std              sum      mean       std
# quality
# 3                83.6  8.360000  1.770875            8.845  0.884500  0.331256
# 4               412.3  7.779245  1.626624           36.780  0.693962  0.220110
# 5              5561.9  8.167254  1.563988          392.965  0.577041  0.164801
# 6              5325.5  8.347179  1.797849          317.395  0.497484  0.160962
# 7              1765.6  8.872362  1.992483           80.380  0.403920  0.145224
# 8               154.2  8.566667  2.119656            7.620  0.423333  0.144914

# %%
df_grouped.columns = df_grouped.columns.to_flat_index()
df_grouped
# Out:
#          (fixed acidity, sum)  (fixed acidity, mean)  (fixed acidity, std)  \
# quality
# 3                        83.6               8.360000              1.770875
# 4                       412.3               7.779245              1.626624
# 5                      5561.9               8.167254              1.563988
# 6                      5325.5               8.347179              1.797849
# 7                      1765.6               8.872362              1.992483
# 8                       154.2               8.566667              2.119656
#
#          (volatile acidity, sum)  (volatile acidity, mean)  \
# quality
# 3                          8.845                  0.884500
# 4                         36.780                  0.693962
# 5                        392.965                  0.577041
# 6                        317.395                  0.497484
# 7                         80.380                  0.403920
# 8                          7.620                  0.423333
#
# ...

# %%
# different aggregation functions to different columns 
df.groupby("quality").agg({
    "fixed acidity": "sum",
    "volatile acidity": ["mean", "std"]
})
# Out:
#         fixed acidity volatile acidity
#                   sum             mean       std
# quality
# 3                83.6         0.884500  0.331256
# 4               412.3         0.693962  0.220110
# 5              5561.9         0.577041  0.164801
# 6              5325.5         0.497484  0.160962
# 7              1765.6         0.403920  0.145224
# 8               154.2         0.423333  0.144914

# %%
# Named aggregations 
df.groupby("quality").agg(
    min_fa=("fixed acidity", "min"),
    var_va=("volatile acidity", "var")
)
# Out:
#          min_fa    var_va
# quality
# 3           6.7  0.109730
# 4           4.6  0.048448
# 5           5.0  0.027159
# 6           4.7  0.025909
# 7           4.9  0.021090
# 8           5.0  0.021000

# %%
df.groupby('quality').agg(
    sum_alcohol = ('alcohol', 'sum'),
    geomean_of_hue = ('pH', lambda x: x.prod() ** (1 / len(x)))
)
# Out:
#          sum_alcohol  geomean_of_hue
# quality
# 3          99.550000        0.100000
# 4         544.050000        0.018868
# 5        6741.700000        0.001468
# 6        6781.633333        0.001567
# 7        2281.716667        0.005025
# 8         217.700000        0.055556

# %%
# custom aggregations
def field_range(s):
    return max(s) - min(s)

df.groupby("quality")["fixed acidity"].agg(min_fixed_acid = "min", max_fixed_acid = "max", max_minus_min= field_range)
# Out:
#          min_fixed_acid  max_fixed_acid  max_minus_min
# quality
# 3                   6.7            11.6            4.9
# 4                   4.6            12.5            7.9
# 5                   5.0            15.9           10.9
# 6                   4.7            14.3            9.6
# 7                   4.9            15.6           10.7
# 8                   5.0            12.6            7.6

# %%
grouped = df.groupby("quality").agg({
    "fixed acidity": "sum",
    "volatile acidity": ["mean", "std"]
}).reset_index()
grouped
# Out:
#   quality fixed acidity volatile acidity
#                     sum             mean       std
# 0       3          83.6         0.884500  0.331256
# 1       4         412.3         0.693962  0.220110
# 2       5        5561.9         0.577041  0.164801
# 3       6        5325.5         0.497484  0.160962
# 4       7        1765.6         0.403920  0.145224
# 5       8         154.2         0.423333  0.144914

# %%
df1 = df.assign(testcol1=lambda df: df.pH/2, testcol2=lambda df: df.pH/2)
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Apply function
def add_3(x):
   return x+3
df1.pH = df1.pH.apply(add_3)
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df1[['pH','testcol1']] = df1[['pH','testcol1']].apply(add_3)
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df1[['pH','testcol1']] = df1[['pH','testcol1']].apply(lambda x : x+9000, axis=1)
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df1.testcol2 = df1.testcol2.apply(lambda x : x + 100 if x > 9.2 else x-100)
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# List comprehension to create a new column
df1['squared_density'] = [i-1 for i in df1['density']]
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Fillter rows and columns 
print(df1.testcol1)
print(df1["testcol1"])
print(df1[["testcol1"]])
# Out:
# 0       9004.755
# 1       9004.600
# 2       9004.630
# 3       9004.580
# 4       9004.755
#           ...
# 1594    9004.725
# 1595    9004.760
# 1596    9004.710
# 1597    9004.785
# 1598    9004.695
# Name: testcol1, Length: 1599, dtype: float64
# 0       9004.755
# 1       9004.600
# 2       9004.630
# 3       9004.580
# 4       9004.755
#           ...
# 1594    9004.725
# 1595    9004.760
# 1596    9004.710
# 1597    9004.785
# 1598    9004.695
# Name: testcol1, Length: 1599, dtype: float64
#       testcol1
# 0     9004.755
# 1     9004.600
# 2     9004.630
# 3     9004.580
# 4     9004.755
# ...        ...
# 1594  9004.725
# 1595  9004.760
# 1596  9004.710
# 1597  9004.785
# 1598  9004.695
#
# [1599 rows x 1 columns]

# %%
df1[['pH','testcol1']]
# Out:
#            pH  testcol1
# 0     9009.51  9004.755
# 1     9009.20  9004.600
# 2     9009.26  9004.630
# 3     9009.16  9004.580
# 4     9009.51  9004.755
# ...       ...       ...
# 1594  9009.45  9004.725
# 1595  9009.52  9004.760
# 1596  9009.42  9004.710
# 1597  9009.57  9004.785
# 1598  9009.39  9004.695
#
# [1599 rows x 2 columns]

# %%
df1.iloc[:, 0:2]
# Out:
#       fixed acidity  volatile acidity
# 0               7.4             0.700
# 1               7.8             0.880
# 2               7.8             0.760
# 3              11.2             0.280
# 4               7.4             0.700
# ...             ...               ...
# 1594            6.2             0.600
# 1595            5.9             0.550
# 1596            6.3             0.510
# 1597            5.9             0.645
# 1598            6.0             0.310
#
# [1599 rows x 2 columns]

# %%
df1.iloc[[0, 1], [0, 1, 2]]
# Out:
#    fixed acidity  volatile acidity  citric acid
# 0            7.4              0.70          0.0
# 1            7.8              0.88          0.0

# %%
df1.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density       pH  sulphates  \
# 0                 11.0                  34.0   0.9978  9009.51       0.56
# 1                 25.0                  67.0   0.9968  9009.20       0.68
# 2                 15.0                  54.0   0.9970  9009.26       0.65
#
#    alcohol  quality  squared_density  testcol1  testcol2
# 0      9.4        5         0.995605  9004.755     1.755
# 1      9.8        5         0.993610  9004.600     1.600
# 2      9.8        5         0.994009  9004.630     1.630

# %%
# filtering rows index divisible by 3
every_3rd_row = [i % 3 == 0 for i in range(len(df1))]
df1.iloc[every_3rd_row]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 3              11.2             0.280         0.56             1.9      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 9               7.5             0.500         0.36             6.1      0.071
# 12              5.6             0.615         0.00             1.6      0.089
# ...             ...               ...          ...             ...        ...
# 1584            6.7             0.320         0.44             2.4      0.061
# 1587            5.8             0.610         0.11             1.8      0.066
# 1590            6.3             0.550         0.15             1.8      0.077
# 1593            6.8             0.620         0.08             1.9      0.068
# 1596            6.3             0.510         0.13             2.3      0.076
#
# ...

# %%
df1.query('`fixed acidity` > 6.7').shape[0]
# Out:
# 1371

# %%
df1.query('`citric acid` == 0')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700          0.0             1.9      0.076
# 1               7.8             0.880          0.0             2.6      0.098
# 4               7.4             0.700          0.0             1.9      0.076
# 5               7.4             0.660          0.0             1.8      0.075
# 7               7.3             0.650          0.0             1.2      0.065
# ...             ...               ...          ...             ...        ...
# 1455            6.5             0.900          0.0             1.6      0.052
# 1461            6.2             0.785          0.0             2.1      0.060
# 1550            7.1             0.680          0.0             2.3      0.087
# 1551            7.1             0.670          0.0             2.3      0.083
# 1553            7.3             0.735          0.0             2.2      0.080
#
# ...

# %%
df1.query('@every_3rd_row')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 3              11.2             0.280         0.56             1.9      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 9               7.5             0.500         0.36             6.1      0.071
# 12              5.6             0.615         0.00             1.6      0.089
# ...             ...               ...          ...             ...        ...
# 1584            6.7             0.320         0.44             2.4      0.061
# 1587            5.8             0.610         0.11             1.8      0.066
# 1590            6.3             0.550         0.15             1.8      0.077
# 1593            6.8             0.620         0.08             1.9      0.068
# 1596            6.3             0.510         0.13             2.3      0.076
#
# ...

# %%
pH_mean = df1.pH.mean()
df1.query('pH > @pH_mean').shape[0]
# Out:
# 777

# %% [markdown]
# ### subset & assign values

# %%
df1.sulphates = df1.sulphates.apply(lambda x: 1 if x >= 0.72 else x)
df1.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %% [markdown]
# ### Descibe

# %%
df1.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df1.pH.describe()
# Out:
# count    1599.000000
# mean        3.311113
# std         0.154386
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
# COMPUTE SUMMARY STATISTICS FOR NUMERIC VARIABLES
df1.describe(include = [np.number])
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# COMPUTE SUMMARY STATISTICS FOR STRING VARIABLES
# df1.describe(include = ['category'])

# %%
df1.describe(percentiles = [0.01, .1, .9, 0.99])
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 1%          5.200000          0.190000     0.000000        1.400000
# 10%         6.500000          0.310000     0.010000        1.700000
# 50%         7.900000          0.520000     0.260000        2.200000
# 90%        10.700000          0.745000     0.522000        3.600000
# 99%        13.300000          1.020000     0.700200        8.306000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# ...

# %%
rolling_mean = df1.pH.rolling(window=2).mean()
print(rolling_mean.head(10))
# Out:
# 0      NaN
# 1    3.355
# 2    3.230
# 3    3.210
# 4    3.335
# 5    3.510
# 6    3.405
# 7    3.345
# 8    3.375
# 9    3.355
# Name: pH, dtype: float64

# %%
rolling_mean = df1.pH.rolling(window=2, min_periods=1).mean()
print(rolling_mean.head(10))
# Out:
# 0    3.510
# 1    3.355
# 2    3.230
# 3    3.210
# 4    3.335
# 5    3.510
# 6    3.405
# 7    3.345
# 8    3.375
# 9    3.355
# Name: pH, dtype: float64

# %% [markdown]
# ### Drop NA

# %% [markdown]
# df1.dropna(how='all') # Drop only if ALL columns are NaN
# df1.dropna(thresh=2)  # Drop row if it does not have at least two values that are **not** NaN
# df1.dropna(subset=["pH]) # Drop only if NaN in specific column
