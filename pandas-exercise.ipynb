# %%
import pandas as pd
import os

# %%
print(os.listdir())
# Out:
# ['file.txt', 'bear_copy.txt', '.DS_Store', 'pandas-exercise.ipynb', 'cheatsheet_filepreprocessing.md', 'README.md', 'supermarkets', 'pandas_exercises.py', '.gitignore', 'file_processing.py', 'bear2.txt', 'bear1.txt', 'bear.txt', '.git', 'data.txt']

# %%
df1 = pd.read_csv("supermarkets/supermarkets-semi-colons.txt", sep = ";")
df1
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pd.read_excel("supermarkets/supermarkets.xlsx")
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df2.rename(columns= {df2.columns[0]:'ID1', 'Address':'Address1', 'City':'City1' }, inplace=True)
df2
# Out:
#    ID1         Address1          City1             State Country  \
# 0    1     3666 21st St  San Francisco          CA 94114     USA
# 1    2   735 Dolores St  San Francisco          CA 94119     USA
# 2    3      332 Hill St  San Francisco  California 94114     USA
# 3    4     3995 23rd St  San Francisco          CA 94114     USA
# 4    5  1056 Sanchez St  San Francisco        California     USA
# 5    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df2.set_index("ID1", inplace=True, drop=False)
df2
# Out:
#      ID1         Address1          City1             State Country  \
# ID1
# 1      1     3666 21st St  San Francisco          CA 94114     USA
# 2      2   735 Dolores St  San Francisco          CA 94119     USA
# 3      3      332 Hill St  San Francisco  California 94114     USA
# 4      4     3995 23rd St  San Francisco          CA 94114     USA
# 5      5  1056 Sanchez St  San Francisco        California     USA
# 6      6  551 Alvarado St  San Francisco          CA 94114     USA
#
#     Supermarket Name  Number of Employees
# ID1
# 1            Madeira                    8
# 2        Bready Shop                   15
# 3        Super River                   25
# 4         Ben's Shop                   10
# 5            Sanchez                   12
# 6         Richvalley                   20

# %%
df2.set_index("ID1", inplace=True)
df2
# Out:
#             Address1          City1             State Country  \
# ID1
# 1       3666 21st St  San Francisco          CA 94114     USA
# 2     735 Dolores St  San Francisco          CA 94119     USA
# 3        332 Hill St  San Francisco  California 94114     USA
# 4       3995 23rd St  San Francisco          CA 94114     USA
# 5    1056 Sanchez St  San Francisco        California     USA
# 6    551 Alvarado St  San Francisco          CA 94114     USA
#
#     Supermarket Name  Number of Employees
# ID1
# 1            Madeira                    8
# 2        Bready Shop                   15
# 3        Super River                   25
# 4         Ben's Shop                   10
# 5            Sanchez                   12
# 6         Richvalley                   20

# %%
df2.drop(columns= ['Address1', 'City1'], inplace = True)
df2
# Out:
#                 State Country Supermarket Name  Number of Employees
# ID1
# 1            CA 94114     USA          Madeira                    8
# 2            CA 94119     USA      Bready Shop                   15
# 3    California 94114     USA      Super River                   25
# 4            CA 94114     USA       Ben's Shop                   10
# 5          California     USA          Sanchez                   12
# 6            CA 94114     USA       Richvalley                   20

# %%
print(df2.query("State == 'CA 94114' & Country == 'USA'"))
print(df2.query("not (State == 'CA 94114' & Country == 'USA')"))
# Out:
#         State Country Supermarket Name  Number of Employees
# ID1
# 1    CA 94114     USA          Madeira                    8
# 4    CA 94114     USA       Ben's Shop                   10
# 6    CA 94114     USA       Richvalley                   20
#                 State Country Supermarket Name  Number of Employees
# ID1
# 2            CA 94119     USA      Bready Shop                   15
# 3    California 94114     USA      Super River                   25
# 5          California     USA          Sanchez                   12

# %%
df2["Employees"] = [2, 99, 22, 12, 78, 8]
df2["Employees1"] = [1, 9, 55, 11, 7, 91]

# %%
df2.query("abs(Employees - Employees1) > 7")
# Out:
#                 State Country Supermarket Name  Number of Employees  \
# ID1
# 2            CA 94119     USA      Bready Shop                   15
# 3    California 94114     USA      Super River                   25
# 5          California     USA          Sanchez                   12
# 6            CA 94114     USA       Richvalley                   20
#
#      Employees  Employees1
# ID1
# 2           99           9
# 3           22          55
# 5           78           7
# 6            8          91

# %%
df = pd.DataFrame(
    {"fruit": ["apple", "orange", "grape", "grape"], "price": [4, 5, 6, 7]}
)

df.query("price > 4 & fruit == 'grape'")
# Out:
#    fruit  price
# 2  grape      6
# 3  grape      7
